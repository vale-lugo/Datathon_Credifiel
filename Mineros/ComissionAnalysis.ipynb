# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime

# %%
catBank = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\CatBanco.csv")
catEmisora = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\CatEmisora.csv")
catRespuesta = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\CatRespuestaBancos.csv")
listCobro = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobro.csv")
listCobro2022 = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroDetalle2022.csv")
listCobro2023 = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroDetalle2023.csv")
listCobro202 = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroDetalle2024.csv")
listCobro2024 = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroDetalle2025.csv")
listCobroEmisora = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroEmisora.csv")
# Out:
# C:\Users\jimen\AppData\Local\Temp\ipykernel_9392\3962552303.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   listCobro2023 = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\ListaCobroDetalle2023.csv")

# %%
listCobro.head()
# Out:
#    idListaCobro  fechaCreacionLista  idBanco fechaEnvioCobro
# 0         79678  04/01/2022 11:16AM       12      04/01/2022
# 1         79746   04/01/2022 6:36PM       12      04/01/2022
# 2         80111   11/01/2022 2:51PM       12      11/01/2022
# 3         80314  13/01/2022 11:44AM       12      13/01/2022
# 4         80507   14/01/2022 6:09PM       12      14/01/2022

# %%
listCobro2024.head()
# Out:
#    idListaCobro  idCredito  consecutivoCobro  idBanco  montoExigible  \
# 0        155938     738973          41396434        2         622.87
# 1        155938     739017          41396435        2        1069.11
# 2        155939     739185          41396436        2        4340.83
# 3        155940     732324          41396437        2        2134.21
# 4        155940     737028          41396438        2         815.76
#
#    montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco
# 0       622.87          0.00             NaN               4.0
# 1      1069.11          0.00             NaN               4.0
# 2      4340.83       4340.83      02/01/2025               0.0
# 3      2134.21          0.00             NaN               4.0
# 4       815.76          0.00             NaN               4.0

# %%
listCobro2024 = listCobro2024.drop(columns={"idBanco"})
df2024 = listCobro2024.merge(listCobro, on="idListaCobro", how="left")
df2024
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 0              155938     738973          41396434         622.87
# 1              155938     739017          41396435        1069.11
# 2              155939     739185          41396436        4340.83
# 3              155940     732324          41396437        2134.21
# 4              155940     737028          41396438         815.76
# ...               ...        ...               ...            ...
# 2114167        162271     741795          44299050         980.32
# 2114168        162271     741795          44299051        1633.86
# 2114169        162271     742470          44299052         810.44
# 2114170        162271     742470          44299053        1350.74
# 2114171        162271     742470          44299054         540.30
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 0             622.87          0.00             NaN               4.0
# ...

# %%
dfBanorte2024 = df2024[df2024["idBanco"] == 72]
dfSantander2024 = df2024[df2024["idBanco"] == 14]
dfBBVA2024 = df2024[df2024["idBanco"] == 12]
dfBanamex2024 = df2024[df2024["idBanco"] == 2]

# %%
dfBanorte2024["idRespuestaBanco"] =dfBanorte2024["idRespuestaBanco"].fillna(0.0)
dfBanorte2024.isna().sum()
# Out:
# C:\Users\jimen\AppData\Local\Temp\ipykernel_9392\2018960037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfBanorte2024["idRespuestaBanco"] =dfBanorte2024["idRespuestaBanco"].fillna(0.0)
# idListaCobro              0
# idCredito                 0
# consecutivoCobro          0
# montoExigible             0
# montoCobrar               0
# montoCobrado              0
# fechaCobroBanco       49337
# idRespuestaBanco          0
# fechaCreacionLista        0
# idBanco                   0
# fechaEnvioCobro           0
# dtype: int64

# %%
dfBanorte2024[dfBanorte2024["montoExigible"] != dfBanorte2024["montoCobrado"]].value_counts()
# Out:
# idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  montoCobrado  fechaCobroBanco  idRespuestaBanco  fechaCreacionLista  idBanco  fechaEnvioCobro
# 156938        713716     41751562          713.28         713.28       588.28        12/02/2025       0.0               27/01/2025 5:37AM   72       27/01/2025         1
# 157508        681414     42071885          636.13         636.13       381.68        12/02/2025       0.0               05/02/2025 10:51AM  72       05/02/2025         1
#               703264     42071764          878.00         878.00       1755.99       12/02/2025       0.0               05/02/2025 10:51AM  72       05/02/2025         1
#               705085     42071829          321.93         321.93       128.77        12/02/2025       0.0               05/02/2025 10:51AM  72       05/02/2025         1
# ...

# %%
dfSantander2024.isna().sum()
# Out:
# idListaCobro              0
# idCredito                 0
# consecutivoCobro          0
# montoExigible             0
# montoCobrar               0
# montoCobrado              0
# fechaCobroBanco       28117
# idRespuestaBanco        202
# fechaCreacionLista        0
# idBanco                   0
# fechaEnvioCobro           0
# dtype: int64

# %%
dfSantander2024["idRespuestaBanco"] = dfSantander2024["idRespuestaBanco"].fillna(13)
# Out:
# C:\Users\jimen\AppData\Local\Temp\ipykernel_9392\248686460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSantander2024["idRespuestaBanco"] = dfSantander2024["idRespuestaBanco"].fillna(13)

# %%
dfBBVA2024.isna().sum()
# Out:
# idListaCobro                0
# idCredito                   0
# consecutivoCobro            0
# montoExigible               0
# montoCobrar                 0
# montoCobrado                0
# fechaCobroBanco       1159155
# idRespuestaBanco         2830
# fechaCreacionLista          0
# idBanco                     0
# fechaEnvioCobro             0
# dtype: int64

# %%
dfBBVA2024[dfBBVA2024["idRespuestaBanco"].isnull()]
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 202828         156642     127335          41667313         282.66
# 202831         156642     155407          41665494         207.80
# 202832         156642     155407          41666299         519.50
# 202833         156642     155407          41666300         311.70
# 202834         156642     163958          41665436         542.32
# ...               ...        ...               ...            ...
# 2111660        162220     466479          44281079         782.53
# 2111661        162220     475597          44281082         375.50
# 2111662        162220     481269          44281080         782.53
# 2111663        162220     482633          44281084         527.17
# 2111664        162220     489813          44281081         973.54
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 202828        282.66           0.0             NaN               NaN
# ...

# %%
dfBBVA2024[(dfBBVA2024["idRespuestaBanco"].isnull()) & (dfBBVA2024["montoCobrado"] != 0.0)]
# Out:
# Empty DataFrame
# Columns: [idListaCobro, idCredito, consecutivoCobro, montoExigible, montoCobrar, montoCobrado, fechaCobroBanco, idRespuestaBanco, fechaCreacionLista, idBanco, fechaEnvioCobro]
# Index: []

# %%
dfBanamex2024.isna().sum()
# Out:
# idListaCobro               0
# idCredito                  0
# consecutivoCobro           0
# montoExigible              0
# montoCobrar                0
# montoCobrado               0
# fechaCobroBanco       789275
# idRespuestaBanco           0
# fechaCreacionLista         0
# idBanco                    0
# fechaEnvioCobro            0
# dtype: int64

# %%
dfBanamex2024[(dfBanamex2024["idRespuestaBanco"].isnull())]
# Out:
# Empty DataFrame
# Columns: [idListaCobro, idCredito, consecutivoCobro, montoExigible, montoCobrar, montoCobrado, fechaCobroBanco, idRespuestaBanco, fechaCreacionLista, idBanco, fechaEnvioCobro]
# Index: []

# %%
dfBanamex2024["idRespuestaBanco"] = dfBanamex2024["idRespuestaBanco"].fillna(13)
# Out:
# C:\Users\jimen\AppData\Local\Temp\ipykernel_9392\3263804002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfBanamex2024["idRespuestaBanco"] = dfBanamex2024["idRespuestaBanco"].fillna(13)

# %%
dfBanorte2024
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 139            155949     490364          41397756         223.46
# 140            155949     664252          41397758         701.17
# 141            155949     709872          41397759        1583.75
# 142            155949     712926          41397757        1203.89
# 252            155954     425211          41398015         486.77
# ...               ...        ...               ...            ...
# 2109979        162201     754625          44267142         426.30
# 2109980        162201     754711          44267264         409.73
# 2109981        162201     754899          44267255         553.76
# 2109982        162201     755181          44267062         575.73
# 2109983        162201     755350          44267257         608.86
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 139           223.46           0.0             NaN               4.0
# ...

# %%
dfBanorte2024Cost =dfBanorte2024.merge(listCobroEmisora, on="idListaCobro", how="left")
dfBanorte2024Cost["count"] = 1
dfBanorte2024Cost
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            155949     490364          41397756         223.46       223.46
# 1            155949     664252          41397758         701.17       701.17
# 2            155949     709872          41397759        1583.75      1583.75
# 3            155949     712926          41397757        1203.89      1203.89
# 4            155954     425211          41398015         486.77       486.77
# ...             ...        ...               ...            ...          ...
# 72235        162201     754625          44267142         426.30       426.30
# 72236        162201     754711          44267264         409.73       409.73
# 72237        162201     754899          44267255         553.76       553.76
# 72238        162201     755181          44267062         575.73       575.73
# 72239        162201     755350          44267257         608.86       608.86
#
# ...

# %%
dfBanorte2024Cost = dfBanorte2024Cost.merge(catEmisora, on="idEmisora", how="left")
dfBanorte2024Cost = dfBanorte2024Cost.drop(columns={"IdBanco"})
dfBanorte2024Cost.columns
# Out:
# Index(['idListaCobro', 'idCredito', 'consecutivoCobro', 'montoExigible',
#        'montoCobrar', 'montoCobrado', 'fechaCobroBanco', 'idRespuestaBanco',
#        'fechaCreacionLista', 'idBanco', 'fechaEnvioCobro', 'idEmisora',
#        'count', 'Nombre', 'Emisora', 'TipoEnvio', 'Costo',
#        'Horario Limite Carga', 'Horario de cobro', 'observaciones'],
#       dtype='object')

# %%
dfBanorte2024Cost
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            155949     490364          41397756         223.46       223.46
# 1            155949     664252          41397758         701.17       701.17
# 2            155949     709872          41397759        1583.75      1583.75
# 3            155949     712926          41397757        1203.89      1203.89
# 4            155954     425211          41398015         486.77       486.77
# ...             ...        ...               ...            ...          ...
# 72235        162201     754625          44267142         426.30       426.30
# 72236        162201     754711          44267264         409.73       409.73
# 72237        162201     754899          44267255         553.76       553.76
# 72238        162201     755181          44267062         575.73       575.73
# 72239        162201     755350          44267257         608.86       608.86
#
# ...

# %%
dfBanorte2024Cost["fechaEnvioCobro"] = pd.to_datetime(dfBanorte2024Cost["fechaEnvioCobro"], errors='coerce')
dfBanorte2024Cost["month"] = dfBanorte2024Cost["fechaEnvioCobro"].dt.month

# %%
dfBanorteSummary = dfBanorte2024Cost.groupby(["month", "idRespuestaBanco"], as_index=False).agg({
    "montoExigible": "sum",
    "montoCobrar": 'sum',
    'montoCobrado': 'sum', 
    "count":"count",
    "Costo":"sum",
    "month":"first",
})
dfBanorteSummary
# Out:
#     idRespuestaBanco  montoExigible  montoCobrar  montoCobrado  count  \
# 0                0.0       17820.43     17820.43      17820.43     16
# 1                3.0        1705.62      1705.62          0.00      3
# 2                4.0       29277.24     29277.24          0.00     40
# 3                0.0       40286.85     40286.85      40286.85     44
# 4                3.0        2036.94      2036.94          0.00      4
# 5                4.0      187573.71    187573.71          0.00    271
# 6                0.0      153057.99    153057.99     153057.99    199
# 7                3.0         592.07       592.07          0.00      1
# 8                4.0      198028.59    198028.59          0.00    319
# 9                0.0        6286.48      6286.48       6286.48      2
# 10               4.0       11707.48     11707.48          0.00     14
# 11               0.0      122998.60    122998.60     124807.69    170
# ...

# %%
dfBanamex2024Cost =dfBanamex2024.merge(listCobroEmisora, on="idListaCobro", how="left")
dfBanamex2024Cost["count"] = 1
dfBanamex2024Cost = dfBanamex2024Cost.merge(catEmisora, on="idEmisora", how="left")
dfBanamex2024Cost = dfBanamex2024Cost.drop(columns={"IdBanco"})
dfBanamex2024Cost["fechaEnvioCobro"] = pd.to_datetime(dfBanamex2024Cost["fechaEnvioCobro"], errors='coerce')
dfBanamex2024Cost["month"] = dfBanamex2024Cost["fechaEnvioCobro"].dt.month
dfBanamex2024Cost
# Out:
#         idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0             155938     738973          41396434         622.87       622.87
# 1             155938     739017          41396435        1069.11      1069.11
# 2             155939     739185          41396436        4340.83      4340.83
# 3             155940     732324          41396437        2134.21      2134.21
# 4             155940     737028          41396438         815.76       815.76
# ...              ...        ...               ...            ...          ...
# 804999        162271     741795          44299050         980.32       980.32
# 805000        162271     741795          44299051        1633.86      1633.86
# 805001        162271     742470          44299052         810.44       810.44
# 805002        162271     742470          44299053        1350.74      1350.74
# 805003        162271     742470          44299054         540.30       540.30
#
# ...

# %%
dfBanamexSummary = dfBanamex2024Cost.groupby(["month", "idRespuestaBanco"], as_index=False).agg({
    "montoExigible": "sum",
    "montoCobrar": 'sum',
    'montoCobrado': 'sum', 
    "count":"count",
    "Costo":"sum",
    "month":"first",
})
dfBanamexSummary
# Out:
#     idRespuestaBanco  montoExigible  montoCobrar  montoCobrado  count  \
# 0                0.0      127827.46    127827.46     127827.46    186
# 1                2.0         318.07       318.07          0.00      1
# 2                4.0     2985728.15   2985728.15          0.00   6157
# 3                0.0      138383.48    138383.48     138383.48    202
# 4                2.0        5589.11      5589.11          0.00     12
# 5                4.0     4851043.37   4851043.37          0.00   7946
# 6                8.0        6082.57      6082.57          0.00     11
# 7                0.0      131648.75    131648.75     131648.75    190
# 8                2.0        3536.58      3536.58          0.00      6
# 9                3.0        1349.85      1349.85          0.00      3
# 10               4.0     3529530.17   3529530.17          0.00   5552
# 11               8.0         769.26       769.26          0.00      3
# ...

# %%
dfBBVA2024 =dfBBVA2024.merge(listCobroEmisora, on="idListaCobro", how="left")
dfBBVA2024["count"] = 1

# %%
dfBBVA2024Good = dfBBVA2024[dfBBVA2024["idRespuestaBanco"] == 0.0]
dfBBVA2024Bad = dfBBVA2024[dfBBVA2024["idRespuestaBanco"] != 0.0]
dfBBVA2024Good =dfBBVA2024Good.merge(catEmisora, on="idEmisora", how="left")
dfBBVA2024Bad =dfBBVA2024Bad.merge(catEmisora, on="idEmisora", how="left")
dfBBVA2024Bad["Costo"] = 0
dfBBVA2024Cost = pd.concat([dfBBVA2024Good, dfBBVA2024Bad], ignore_index=True)
dfBBVA2024Good
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            155947     739598          41397720        1782.90      1782.90
# 1            155950     661415          41397842         391.26       391.26
# 2            155988     405159          41402462         450.91       450.91
# 3            156003     379056          41402809         370.00       370.00
# 4            156003     409753          41402816         649.59       649.59
# ...             ...        ...               ...            ...          ...
# 32867        162232     712253          44282581         137.69       137.69
# 32868        162232     714046          44282595         948.54       948.54
# 32869        162232     734228          44281582         123.79       123.79
# 32870        162232     736792          44281618         150.21       150.21
# 32871        162234     133936          44282752         134.60       134.60
#
# ...

# %%
dfBBVA2024Cost[dfBBVA2024Cost["Costo"] == 0]
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 32872          155950      83373          41397840         508.31
# 32873          155950     127335          41397855         706.66
# 32874          155950     155407          41397788         519.50
# 32875          155950     163958          41397780         542.32
# 32876          155950     290264          41397795         854.20
# ...               ...        ...               ...            ...
# 1192022        162234     416184          44282768         268.15
# 1192023        162234     524583          44282769         756.66
# 1192024        162234     524583          44282770        1261.10
# 1192025        162234     524583          44282771         504.44
# 1192026        162241     752266          44282961        1219.25
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 32872         508.31           0.0             NaN               4.0
# ...

# %%
#dfBBVA2024Cost =dfBBVA2024.merge(listCobroEmisora, on="idListaCobro", how="left")
#dfBBVA2024Cost["count"] = 1
#dfBBVA2024Cost = dfBBVA2024Cost.merge(catEmisora, on="idEmisora", how="left")
dfBBVA2024Cost = dfBBVA2024Cost.drop(columns={"IdBanco"})
dfBBVA2024Cost["fechaEnvioCobro"] = pd.to_datetime(dfBBVA2024Cost["fechaEnvioCobro"], errors='coerce')
dfBBVA2024Cost["month"] = dfBBVA2024Cost["fechaEnvioCobro"].dt.month
#dfBBVA2024Cost["Costo"] = dfBBVA2024Cost["idRespuestaBanco"].apply(lambda respuesta: 0 if not 0.0 in respuesta else pass)
dfBBVA2024Cost
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 0              155947     739598          41397720        1782.90
# 1              155950     661415          41397842         391.26
# 2              155988     405159          41402462         450.91
# 3              156003     379056          41402809         370.00
# 4              156003     409753          41402816         649.59
# ...               ...        ...               ...            ...
# 1192022        162234     416184          44282768         268.15
# 1192023        162234     524583          44282769         756.66
# 1192024        162234     524583          44282770        1261.10
# 1192025        162234     524583          44282771         504.44
# 1192026        162241     752266          44282961        1219.25
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 0            1782.90       1782.90      02/01/2025               0.0
# ...

# %%
dfBBVASummary = dfBBVA2024Cost.groupby(["month", "idRespuestaBanco"], as_index=False).agg({
    "montoExigible": "sum",
    "montoCobrar": 'sum',
    'montoCobrado': 'sum', 
    "count":"count",
    "Costo":"sum",
    "month":"first",
})
dfBBVASummary
# Out:
#     idRespuestaBanco  montoExigible  montoCobrar  montoCobrado  count  Costo  \
# 0                0.0       40987.38     40987.38      40987.38     38  300.0
# 1                1.0        6032.91      6032.91          0.00      9    0.0
# 2                2.0         881.15       881.15          0.00      2    0.0
# 3                4.0     1192627.65   1192627.65          0.00   1356    0.0
# 4                8.0       40847.07     40847.07          0.00     52    0.0
# ..               ...            ...          ...           ...    ...    ...
# 57               2.0       39596.11     39596.11          0.00     39    0.0
# 58               3.0       46858.29     46858.29          0.00     38    0.0
# 59               4.0    45113677.05  45113677.05          0.00  71546    0.0
# 60               8.0       52767.54     52767.54          0.00     50    0.0
# 61              13.0      360060.61    360060.61          0.00    688    0.0
#
#     month
# 0     1.0
# 1     1.0
# ...

# %%
dfSantander2024
# Out:
#          idListaCobro  idCredito  consecutivoCobro  montoExigible  \
# 244            155951     366046          41397864         486.47
# 245            155951     427609          41397862         248.25
# 246            155951     683653          41397865         586.89
# 247            155951     686634          41397861         586.89
# 248            155951     689508          41397866        1242.71
# ...               ...        ...               ...            ...
# 2105816        162150     754512          44254063         929.42
# 2105817        162150     754605          44253985         629.23
# 2105818        162150     755017          44254031         693.62
# 2105819        162150     755243          44253995         134.31
# 2105820        162150     755255          44254070         752.15
#
#          montoCobrar  montoCobrado fechaCobroBanco  idRespuestaBanco  \
# 244           486.47          0.00             NaN               4.0
# ...

# %%
dfSantander2024 = dfSantander2024.merge(listCobroEmisora, on="idListaCobro", how="left")
dfSantander2024["count"] = 1

# %%
sAcepted = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\SantanderAcepted.csv")
sRejected = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\SantanderRejected.csv")
sRejected
# Out:
#    idEmisora                                             Nombre  IdBanco  \
# 0          8                   SANTANDER TRADICIONAL REINTENTO        14
# 1          9                        SANTANDER CLABE TRADICIONAL       14
# 2         10                                  SANTANDER CUENTA        14
# 3         11                      SANTANDER CLABE INTERBANCARIO       14
# 4         66  Santander Interbancario Cuenta Periodo Actual ...       14
# 5         47  Santander Tradicional Cuenta Periodo Actual   ...       14
# 6         68  Santander Excepciones Cuenta                  ...       14
# 7         35  Santander Reintentos                          ...       14
# 8         69  Santander Reintentos Cuenta                   ...       14
# 9         70  Santander Interbancario Cuenta Excepciones    ...       14
#
#      Emisora      TipoEnvio  Costo Horario Limite Carga  \
# 0  REINTENTO    TRADICIONAL   1.42         6:40 - 17:40
# ...

# %%
dfS2024Good = dfSantander2024[dfSantander2024["idRespuestaBanco"] == 0.0]
dfS2024Bad = dfSantander2024[dfSantander2024["idRespuestaBanco"] != 0.0]
dfS2024Good = dfS2024Good.merge(sAcepted, on="idEmisora", how="left")
dfS2024Bad = dfS2024Bad.merge(sRejected, on="idEmisora", how="left")
#dfS2024Bad["Costo"] = 0
dfS2024Cost = pd.concat([dfS2024Good, dfS2024Bad], ignore_index=True)
dfS2024Bad
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            155951     366046          41397864         486.47       486.47
# 1            155951     427609          41397862         248.25       248.25
# 2            155951     683653          41397865         586.89       586.89
# 3            155951     686634          41397861         586.89       586.89
# 4            155951     689508          41397866        1242.71      1242.71
# ...             ...        ...               ...            ...          ...
# 28112        162150     754406          44253987         971.65       971.65
# 28113        162150     754512          44254063         929.42       929.42
# 28114        162150     754605          44253985         629.23       629.23
# 28115        162150     755017          44254031         693.62       693.62
# 28116        162150     755255          44254070         752.15       752.15
#
# ...

# %%
dfS2024Cost
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            156075     659948          41419090         782.52       782.52
# 1            156075     662194          41419085         313.01       313.01
# 2            156075     677365          41419075        2826.13      2826.13
# 3            156075     681542          41419078        2561.45      2561.45
# 4            156075     686356          41419086        1280.64      1280.64
# ...             ...        ...               ...            ...          ...
# 44896        162150     754406          44253987         971.65       971.65
# 44897        162150     754512          44254063         929.42       929.42
# 44898        162150     754605          44253985         629.23       629.23
# 44899        162150     755017          44254031         693.62       693.62
# 44900        162150     755255          44254070         752.15       752.15
#
# ...

# %%
dfS2024Cost = dfS2024Cost.drop(columns={"IdBanco"})
dfS2024Cost["fechaEnvioCobro"] = pd.to_datetime(dfS2024Cost["fechaEnvioCobro"], errors='coerce')
dfS2024Cost["month"] = dfS2024Cost["fechaEnvioCobro"].dt.month
#dfBBVA2024Cost["Costo"] = dfBBVA2024Cost["idRespuestaBanco"].apply(lambda respuesta: 0 if not 0.0 in respuesta else pass)
dfS2024Cost
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            156075     659948          41419090         782.52       782.52
# 1            156075     662194          41419085         313.01       313.01
# 2            156075     677365          41419075        2826.13      2826.13
# 3            156075     681542          41419078        2561.45      2561.45
# 4            156075     686356          41419086        1280.64      1280.64
# ...             ...        ...               ...            ...          ...
# 44896        162150     754406          44253987         971.65       971.65
# 44897        162150     754512          44254063         929.42       929.42
# 44898        162150     754605          44253985         629.23       629.23
# 44899        162150     755017          44254031         693.62       693.62
# 44900        162150     755255          44254070         752.15       752.15
#
# ...

# %%
dfSSummary = dfS2024Cost.groupby(["month", "idRespuestaBanco"], as_index=False).agg({
    "montoExigible": "sum",
    "montoCobrar": 'sum',
    'montoCobrado': 'sum', 
    "count":"count",
    "Costo":"sum",
    "month":"first",
})
dfSSummary
# Out:
#     idRespuestaBanco  montoExigible  montoCobrar  montoCobrado  count  \
# 0                0.0       94555.26     94555.26      94555.26    109
# 1                4.0      112546.75    112546.75          0.00    177
# 2                0.0      102472.02    102472.02     102472.02     60
# 3                2.0        3512.00      3512.00          0.00      3
# 4                4.0      149680.99    149680.99          0.00    228
# 5                0.0       94944.98     94944.98      94944.98     75
# 6                2.0        1756.00      1756.00          0.00      1
# 7                4.0      108973.71    108973.71          0.00    141
# 8                0.0       12244.92     12244.92      12244.92      4
# 9                4.0        7148.69      7148.69          0.00     10
# 10               0.0       45507.03     45507.03      45507.03     53
# 11               3.0         591.68       591.68          0.00      1
# ...

# %%
dfSSummary["Costo"].sum()
# Out:
# np.float64(58977.26999999998)

# %%
dfBBVASummary["Costo"].sum()
# Out:
# np.float64(106882.0)

# %%
dfBanorteSummary["Costo"].sum()
# Out:
# np.float64(98920.0)

# %%
dfBanamexSummary["Costo"].sum()
# Out:
# np.float64(301465.5)

# %%
a = dfS2024Cost.groupby(["idRespuestaBanco", "idEmisora"]).agg({"count":"count"})
a
# Out:
#                             count
# idRespuestaBanco idEmisora
# 0.0              9          15529
#                  10          1255
# 2.0              9             95
#                  10            83
# 3.0              9             65
#                  10             4
# 4.0              9          23549
#                  10          3901
# 8.0              9            204
#                  10            13
# 10.0             10             1
# 13.0             9            202

# %%
a = dfBanorte2024Cost.groupby(["idRespuestaBanco", "idEmisora"]).agg({"count":"count"})
a
# Out:
#                             count
# idRespuestaBanco idEmisora
# 0.0              12         23005
#                  13           640
#                  15             4
# 1.0              12             9
# 2.0              12             7
# 3.0              12           182
#                  13             4
# 4.0              12         41917
#                  13          5308
#                  15             2
# 26.0             12          1026
#                  13            48
# 30.0             12            82
# 88.0             12             6

# %%
a = dfBanamex2024Cost.groupby(["idRespuestaBanco", "idEmisora"]).agg({"count":"count"})
a
# Out:
#                              count
# idRespuestaBanco idEmisora
# 0.0              1            5503
#                  2             142
#                  5           10084
# 1.0              1               6
#                  2               1
# 2.0              1              44
#                  2              18
#                  5             217
# 3.0              1              32
#                  2               5
#                  5             130
# 4.0              1          280466
#                  2            8338
#                  5          499709
# 8.0              1             170
#                  5             139

# %%
a = dfBBVA2024Cost.groupby(["idRespuestaBanco", "idEmisora"]).agg({"count":"count"})
a
# Out:
#                              count
# idRespuestaBanco idEmisora
# 0.0              6            4015
#                  17          17510
#                  18            286
#                  19            214
#                  20              2
#                  21           6453
#                  22            139
#                  25           4253
# 1.0              6              35
#                  25             92
# 2.0              6              18
#                  21             18
#                  25             69
# 3.0              6              21
#                  17            100
#                  21            140
#                  25             16
# 4.0              6          663549
#                  17          48254
#                  18           2266
#                  19           1654
#                  20             41
#                  21         415663
#                  22           5164
#                  25          11127
# ...

# %%
efectividadGlobal = pd.read_csv("C:\\Users\\jimen\\Documents\\Credifiel\\ExtraccionDomiVersionFinal\\efectividad_global_creditos.csv")
efectividadGlobal = efectividadGlobal.drop(columns={"montoExigible", "consecutivoCobro", "montoCobrado"})
efectividadGlobal
# Out:
#        idCredito  Capital Inicial     Pagaré  porcentaje_cobrado_total  \
# 0         610522          15576.0   31917.60                  0.000000
# 1         610562          12941.0   26342.88                  0.000000
# 2         610671          10000.0   20491.68                  8.538200
# 3         610686          14901.0   30332.64                  9.537011
# 4         610741          15222.0   30985.92                  4.240836
# ...          ...              ...        ...                       ...
# 12172     739176          26886.0   75538.56                  5.853307
# 12173     739185          37080.0  104179.92                  0.000000
# 12174     739199          10000.0   28096.08                 11.706700
# 12175     739220          70000.0  196671.80                  5.403071
# 12176     739445          70000.0  196671.80                  0.000000
#
#        porcentaje_exigible_total  diferencia_pagare_capital
# ...

# %%
dfS2024Cost
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            156075     659948          41419090         782.52       782.52
# 1            156075     662194          41419085         313.01       313.01
# 2            156075     677365          41419075        2826.13      2826.13
# 3            156075     681542          41419078        2561.45      2561.45
# 4            156075     686356          41419086        1280.64      1280.64
# ...             ...        ...               ...            ...          ...
# 44896        162150     754406          44253987         971.65       971.65
# 44897        162150     754512          44254063         929.42       929.42
# 44898        162150     754605          44253985         629.23       629.23
# 44899        162150     755017          44254031         693.62       693.62
# 44900        162150     755255          44254070         752.15       752.15
#
# ...

# %%
dfS2024CostF = dfS2024Cost.merge(efectividadGlobal, on="idCredito", how="left")
dfS2024CostF
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            156075     659948          41419090         782.52       782.52
# 1            156075     662194          41419085         313.01       313.01
# 2            156075     677365          41419075        2826.13      2826.13
# 3            156075     681542          41419078        2561.45      2561.45
# 4            156075     686356          41419086        1280.64      1280.64
# ...             ...        ...               ...            ...          ...
# 44896        162150     754406          44253987         971.65       971.65
# 44897        162150     754512          44254063         929.42       929.42
# 44898        162150     754605          44253985         629.23       629.23
# 44899        162150     755017          44254031         693.62       693.62
# 44900        162150     755255          44254070         752.15       752.15
#
# ...

# %%
dfS2024CostF = dfS2024CostF.dropna()

# %%
dfBBVA2024CostF = dfBBVA2024Cost.merge(efectividadGlobal, on="idCredito", how="left")
dfBBVA2024CostF = dfBBVA2024CostF.dropna()
dfBBVA2024CostF
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 1            155950     661415          41397842         391.26       391.26
# 10           156013     684952          41405235         586.89       586.89
# 11           156013     725741          41405309        1891.08      1891.08
# 12           156044     647190          41413073        1260.76      1260.76
# 13           156044     651123          41413024         610.51       610.51
# ...             ...        ...               ...            ...          ...
# 31582        161817     738825          44118178         844.43       844.43
# 31583        161817     738825          44118179         506.66       506.66
# 31584        161817     738825          44120756         337.77       337.77
# 31587        161818     661899          44121654          94.09        94.09
# 31588        161818     661899          44121686         141.13       141.13
#
# ...

# %%
dfBanamex2024CostF = dfBanamex2024Cost.merge(efectividadGlobal, on="idCredito", how="left")
dfBanamex2024CostF = dfBanamex2024CostF.dropna()
dfBanamex2024CostF
# Out:
#         idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 2             155939     739185          41396436        4340.83      4340.83
# 1223          156072     649014          41419037        2684.72      2684.72
# 1226          156072     679235          41419029        1280.64      1280.64
# 1227          156072     679611          41419030        1280.72      1280.72
# 1230          156072     681326          41419016        2134.54      2134.54
# ...              ...        ...               ...            ...          ...
# 747791        161812     737209          44114592        3853.65      3853.65
# 749053        161813     711537          44115854         251.12       251.12
# 749054        161813     711537          44115855         418.54       418.54
# 749055        161813     711537          44115856         167.42       167.42
# 749795        161814     731106          44116596         535.29       535.29
#
# ...

# %%
dfBanorte2024CostF = dfBanorte2024Cost.merge(efectividadGlobal, on="idCredito", how="left")
dfBanorte2024CostF = dfBanorte2024CostF.dropna()
dfBanorte2024CostF
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 5            156037     644994          41406205         595.76       595.76
# 6            156037     645571          41406345         143.43       143.43
# 7            156037     647112          41406320         657.33       657.33
# 8            156037     647211          41406479         560.54       560.54
# 9            156037     647539          41406333         695.25       695.25
# ...             ...        ...               ...            ...          ...
# 69494        161742     654046          44071562         254.45       254.45
# 69502        161742     655268          44071676         174.26       174.26
# 69512        161742     657534          44071421         374.04       374.04
# 69513        161742     657534          44071422         561.06       561.06
# 69514        161742     657534          44071423         935.11       935.11
#
# ...

# %%
dfBB2024CostF.columns
# Out:
# Index(['idListaCobro', 'idCredito', 'consecutivoCobro', 'montoExigible',
#        'montoCobrar', 'montoCobrado', 'fechaCobroBanco', 'idRespuestaBanco',
#        'fechaCreacionLista', 'idBanco', 'fechaEnvioCobro', 'idEmisora',
#        'count', 'Nombre', 'Emisora', 'TipoEnvio', 'Costo',
#        'Horario Limite Carga', 'Horario de cobro', 'observaciones', 'month',
#        'Capital Inicial', 'Pagaré', 'porcentaje_cobrado_total',
#        'porcentaje_exigible_total', 'diferencia_pagare_capital'],
#       dtype='object')

# %%
dfBanorte2024CostF["Emisora"].unique()
# Out:
# array(['00496', '00639'], dtype=object)

# %%
df2024CostF1 = pd.concat([dfBanorte2024CostF, dfS2024CostF], ignore_index=True)
df2024CostF2 = pd.concat([dfBBVA2024CostF, dfBanamex2024CostF], ignore_index=True)

# %%
df2024CostF = pd.concat([df2024CostF1, df2024CostF2], ignore_index=True)
df2024CostF =df2024CostF.drop(columns={"count", "Nombre", "Emisora", "TipoEnvio"})
df2024CostF
# Out:
#        idListaCobro  idCredito  consecutivoCobro  montoExigible  montoCobrar  \
# 0            156037     644994          41406205         595.76       595.76
# 1            156037     645571          41406345         143.43       143.43
# 2            156037     647112          41406320         657.33       657.33
# 3            156037     647211          41406479         560.54       560.54
# 4            156037     647539          41406333         695.25       695.25
# ...             ...        ...               ...            ...          ...
# 27246        161812     737209          44114592        3853.65      3853.65
# 27247        161813     711537          44115854         251.12       251.12
# 27248        161813     711537          44115855         418.54       418.54
# 27249        161813     711537          44115856         167.42       167.42
# 27250        161814     731106          44116596         535.29       535.29
#
# ...

# %%
df2024CostF.to_csv("datos.csv")

# %%
df2024CostF.columns
# Out:
# Index(['idListaCobro', 'idCredito', 'consecutivoCobro', 'montoExigible',
#        'montoCobrar', 'montoCobrado', 'fechaCobroBanco', 'idRespuestaBanco',
#        'fechaCreacionLista', 'idBanco', 'fechaEnvioCobro', 'idEmisora',
#        'Costo', 'Horario Limite Carga', 'Horario de cobro', 'observaciones',
#        'month', 'Capital Inicial', 'Pagaré', 'porcentaje_cobrado_total',
#        'porcentaje_exigible_total', 'diferencia_pagare_capital'],
#       dtype='object')
